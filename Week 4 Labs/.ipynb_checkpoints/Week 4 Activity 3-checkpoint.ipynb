# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("PeoplesFavourites-1.csv")
df
# Out:
#                Job Title          Interests    Interests.1   Education Level   \
# 0           Chef Manager              Music     Accounting     Junior college
# 1       Machine Operator          Sociology         Health  Technical college
# 2       IT Support Staff               none            NaN  Public university
# 3     Executive Director  Modern Literature           none        High school
# 4             Accountant              Latin  Language Arts      Middle school
# ...                  ...                ...            ...                ...
# 1008     Health Educator      Language Arts        Ecology          Gymnasium
# 1009            Operator         Basic Math         French          Gymnasium
# 1010      HR Coordinator            Spanish      Economics    Graduate school
# 1011     Business Broker            Science      Economics        High school
# 1012    IT Support Staff                  0           none  Public university
#
# ...

# %%
# A number of different symbols (including space) have been used for null values, select and apply a consistant approach to their representation.
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)
df.replace(['0', 0, 'none', None, 'null'], np.nan, inplace=True)
df.fillna(method='ffill')
df
# Out:
#                Job Title          Interests    Interests.1   Education Level   \
# 0           Chef Manager              Music     Accounting     Junior college
# 1       Machine Operator          Sociology         Health  Technical college
# 2       IT Support Staff                NaN            NaN  Public university
# 3     Executive Director  Modern Literature            NaN        High school
# 4             Accountant              Latin  Language Arts      Middle school
# ...                  ...                ...            ...                ...
# 1008     Health Educator      Language Arts        Ecology          Gymnasium
# 1009            Operator         Basic Math         French          Gymnasium
# 1010      HR Coordinator            Spanish      Economics    Graduate school
# 1011     Business Broker            Science      Economics        High school
# 1012    IT Support Staff                NaN            NaN  Public university
#
# ...

# %%
# Remove any customer data that has missing data in any of the following first name, last name and email.
columns = ['Email', 'First Name', 'Last Name']
for column in columns:
    df = df[df[column].notna()]
df
# Out:
#                   Job Title              Interests         Interests.1  \
# 0              Chef Manager                  Music          Accounting
# 1          Machine Operator              Sociology              Health
# 3        Executive Director      Modern Literature                 NaN
# 4                Accountant                  Latin       Language Arts
# 5     Systems Administrator                 Speech                 NaN
# ...                     ...                    ...                 ...
# 997             Stockbroker      Modern Literature           Economics
# 998                 Auditor  Design and technology             Grammar
# 999                    Cook             Accounting             Science
# 1000      Food Technologist                Spanish                 Art
# 1001       Insurance Broker                 German  Instrumental Music
#
#        Education Level           City            Food             Food.1  \
# ...

# %%
# Anonymize the data by removing the customer names (first and last name) replacing with a unique identifier.
df.columns
labels = ['First Name', 'Last Name']
df.drop(columns=labels, inplace= True)
df['unique_id'] = df.index
df.head()
# Out:
#                Job Title          Interests    Interests.1   Education Level   \
# 0           Chef Manager              Music     Accounting     Junior college
# 1       Machine Operator          Sociology         Health  Technical college
# 3     Executive Director  Modern Literature            NaN        High school
# 4             Accountant              Latin  Language Arts      Middle school
# 5  Systems Administrator             Speech            NaN     Junior college
#
#            City           Food        Food.1           Car    Income  \
# 0       Fremont     McDonald's       Sun-Pat       Audi Q7  801401.0
# 1      Honolulu          Heinz        Magnum  Citroen Nemo   29159.0
# 3        Boston            KFC           NaN       Audi Q1  316511.0
# 4  Fayetteville         Domino  Papadopoulos        BMW X6  442632.0
# 5       Houston  Betty Crocker           NaN        BMW X3  235058.0
#
#        Movie    Movie.1                          Email  unique_id
# ...

# %%
# Once complete export the data to a new file
df.to_csv('Activity3_results.csv', index=False)
